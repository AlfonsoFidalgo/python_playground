# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel('dsa_sqr_100417.xlsx')

# %%
df[df['Conversions'] > 0].describe()
# Out:
#             Clicks   Impressions        CTR   Avg. CPC        Cost  \
# count    41.000000     41.000000  41.000000  41.000000   41.000000
# mean   1638.487805   6310.048780   0.344093   0.099512  139.652195
# std    2425.218321  10010.823193   0.115873   0.064921  227.325144
# min      55.000000    110.000000   0.185700   0.030000    3.330000
# 25%     361.000000    882.000000   0.257900   0.050000   26.920000
# 50%     511.000000   1861.000000   0.303900   0.090000   49.300000
# 75%    1387.000000   5231.000000   0.421100   0.110000  115.580000
# max    9619.000000  39248.000000   0.597400   0.370000  961.660000
#
#        Conversions  Cost / conv.  Conv. rate  All conv.
# count    41.000000     41.000000   41.000000  41.000000
# mean      4.878049     29.667317    0.006912   4.878049
# std       7.372907     24.672317    0.009497   7.372907
# min       1.000000      3.330000    0.000300   1.000000
# 25%       1.000000     16.540000    0.002000   1.000000
# ...

# %%
df.head(15)
# Out:
#    Top level categories         Ad group  Clicks  Impressions     CTR  \
# 0                españa    DSA - Top Cat    9351        39248  0.2383
# 1                italia    DSA - Top Cat    6194        20384  0.3039
# 2        estados unidos    DSA - Top Cat    9619        38486  0.2499
# 3               francia    DSA - Top Cat    3388        13094  0.2587
# 4           reino unido    DSA - Top Cat    2554         9593  0.2662
# 5              portugal  DSA - All Pages    1080         3115  0.3467
# 6          países bajos  DSA - All Pages    1113         3986  0.2792
# 7               irlanda  DSA - All Pages     253          446  0.5673
# 8             argentina    DSA - Bad Cat    4353        19819  0.2196
# 9                grecia  DSA - All Pages     823         2093  0.3932
# 10                suiza  DSA - All Pages     470          882  0.5329
# 11             bulgaria  DSA - All Pages     114          245  0.4653
# ...

# %%
df[(df['Conversions'] == 0) & (df['Cost'] > 10)].sort_values(by='Cost', ascending=False)
# Out:
#      Top level categories         Ad group  Clicks  Impressions     CTR  \
# 42                  chile    DSA - Bad Cat    2692        10949  0.2459
# 41               colombia    DSA - Top Cat    1066         5411  0.1970
# 46   república dominicana    DSA - Bad Cat    1437         4926  0.2917
# 94                  japón  DSA - All Pages     552         1151  0.4796
# 61                ecuador  DSA - All Pages     772         2699  0.2860
# 67                chequia  DSA - All Pages     357         1351  0.2642
# 43                  rusia  DSA - All Pages     523         5499  0.0951
# 78                bahamas    DSA - Top Cat     518         1650  0.3139
# 44                turquía  DSA - All Pages     291          514  0.5661
# 63              dinamarca  DSA - All Pages     395         1587  0.2489
# 49              sudáfrica  DSA - All Pages     421         1412  0.2982
# 104           el salvador  DSA - All Pages     434         1927  0.2252
# ...

# %%
sns.clustermap(df['Conversions'])
# Out:
# C:\Users\afidalgo\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\afidalgo\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\matrix.py in calculated_linkage(self)
#     596         try:
# --> 597             return self._calculate_linkage_fastcluster()
#     598         except ImportError:
#
# C:\Users\afidalgo\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\matrix.py in _calculate_linkage_fastcluster(self)
#     576     def _calculate_linkage_fastcluster(self):
# --> 577         import fastcluster
#     578         # Fastcluster has a memory-saving vectorized version, but only
#
# ...
