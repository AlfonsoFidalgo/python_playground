# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Final URL report.xlsx', header=1)

# %%
df.dropna(inplace=True)

# %%
df['URL Clean'] = df['Final URL'].apply(lambda x: x.split('?')[0])

# %%
def parseUrl (url):
    arr = url.split('/')
    if len(arr[len(arr)-1]) == 1:
        return arr[len(arr)-2]
    else:
        return arr[len(arr)-1]

# %%
def categorise (url):
    if '-ttd' in url:
        return 'TTD'
    elif '-t' in url:
        return 'Recommendation'
    elif '-g' in url:
        return 'Group/Category'
    elif '-a' in url:
        return 'Attraction'
    elif '-' not in url:
        return 'TTD'
    else:
        return 'Product'

# %%
def parseCat (str):
    if type(str) != float:
        arr = str.split('\n')
        return arr[0]
    else:
        return "No Cat"

# %%
df['URL Cat'] = df['URL Clean'].apply(parseUrl)

# %%
df['Category'] = df['URL Cat'].apply(categorise)

# %%
df['Destination'] = df['URL Cat'].apply(lambda x: x.split('-')[0])

# %%
df['Attraction'] = df[df['Category'] == 'Attraction']['URL Cat'].apply(lambda x: x.split('-')[1])

# %%
df['Conversions'] = df['Conversions'].apply(lambda x: int(x.split('.')[0].replace(',','')))

# %%
df[['Conversions', 'Destination']][df['Conversions'] > 10]
# Out:
#        Conversions     Destination
# 63              19            d357
# 89              22            d737
# 122             14            d357
# 163             34            d512
# 179             13            d739
# 470             53  www.viator.com
# 491             52            d479
# 532           4562  www.viator.com
# 557             11            d511
# 684             17            d684
# 792             40  www.viator.com
# 832             11            d463
# 856             27            d566
# 879             15            d731
# 892             12             d36
# 919             12            d562
# 991             19             d56
# 1039            33            d357
# 1114            12            d333
# 1151            17            d947
# 1155            28            d511
# 1176            15            d737
# 1184            16            d458
# 1252            21            d512
# 1287            21            d675
# 1371            19            d503
# 1384            17            d562
# 1390            12            d672
# 1441            21  www.viator.com
# 1455            20  www.viator.com
# ...            ...             ...
# 10479           34            d479
# 10489           15            d628
# 10511           61  www.viator.com
# 10522           51            d479
# 10524           15            d973
# 10538           19  www.viator.com
# 10558           13            d332
# 10565           20            d334
# 10609           26  www.viator.com
# 10612           11            d675
# 10640           14            d905
# 10802           11            d479
# 10804           22            d334
# 10974           14            d334
# 11022           21            d522
# 11102           76            d479
# 11228           26  www.viator.com
# 11244           13            d794
# 11271           11            d675
# 11290           17            d479
# 11374           27            d651
# 11377          121  www.viator.com
# 11433           13            d479
# 11490           11            d815
# 11578           13            d737
# 11585           13            d479
# 11602           23            d529
# 11614           41  www.viator.com
# 11626           11  www.viator.com
# 11653           43            d525
#
# [282 rows x 2 columns]

# %%
df[df['Category'] == 'Attraction'][['Conversions','Attraction']].groupby(by='Attraction').sum().sort_values(by='Conversions', ascending=False)
# Out:
#             Conversions
# Attraction
# a89                 494
# a710                264
# a576                235
# a86                 190
# a73                 170
# a701                165
# a727                130
# a783                120
# a113                111
# a845                110
# a4876               104
# a112                 99
# a7                   89
# a1400                83
# a88                  77
# a90                  75
# a22115               75
# a2068                72
# a706                 65
# a8969                64
# a1189                62
# a38                  61
# a590                 61
# a1318                55
# a84                  53
# a668                 47
# a835                 47
# a106                 47
# a78                  46
# a290                 46
# ...                 ...
# a4663                 1
# a402                  1
# a1136                 1
# a6603                 1
# a1566                 1
# a12407                1
# a20815                1
# a12903                1
# a15306                1
# a1532                 1
# a15539                1
# a12593                1
# a342                  1
# a2001                 1
# a12640                1
# a1053                 1
# a12702                1
# a16590                1
# a15898                1
# a712                  1
# a15955                1
# a3742                 1
# a16209                1
# a379                  1
# a1184                 1
# a16493                1
# a16571                1
# a12757                1
# a1276                 1
# a6406                 1
#
# [427 rows x 1 columns]

# %%
something = df[df['Category'] == 'Attraction'][['Conversions','Destination','Attraction']].pivot_table(values='Conversions', index=['Destination','Attraction'], aggfunc='sum')

# %%
summary = pd.DataFrame(data=something)

# %%
df_attractions = df[df['Category'] == 'Attraction']

# %%
df_attractions.head()
# Out:
#                                             Final URL  Clicks  Impressions  \
# 3   https://www.viator.com/Cancun-attractions/Tulu...      26          244
# 9   https://www.viator.com/Tokyo-attractions/Mt-Fu...      12          142
# 10  https://www.viator.com/London-attractions/Lond...      66          240
# 16  https://www.viator.com/Kyoto-attractions/Kyoto...      24          260
# 18  https://www.viator.com/Florence-attractions/Uf...       8           91
#
#        CTR  Avg. CPC   Cost  Avg. position  Conversions  Cost / conv.  \
# 3   10.66%      0.74  19.17            2.7            1         19.17
# 9    8.45%      0.73   8.76            3.4            2          4.38
# 10  27.50%      0.57  37.34            1.4            1         37.34
# 16   9.23%      0.36   8.60            1.7            2          4.30
# 18   8.79%      1.94  15.51            3.0            1         15.51
#
#    Conv. rate All conv.                                          URL Clean  \
# 3       3.85%       1.0  https://www.viator.com/Cancun-attractions/Tulu...
# 9      16.67%       2.0  https://www.viator.com/Tokyo-attractions/Mt-Fu...
# 10      1.52%       4.0  https://www.viator.com/London-attractions/Lond...
# 16      8.33%       4.0  https://www.viator.com/Kyoto-attractions/Kyoto...
# 18     12.50%       1.0  https://www.viator.com/Florence-attractions/Uf...
#
#        URL Cat    Category Destination Attraction
# 3     d631-a79  Attraction        d631        a79
# 9     d334-a86  Attraction        d334        a86
# 10  d737-a1400  Attraction        d737      a1400
# 16   d332-a194  Attraction        d332       a194
# 18   d519-a117  Attraction        d519       a117

# %%
df_attractions[['URL Clean', 'Destination', 'Attraction', 'Conversions']].sort_values('Conversions', ascending=False)
# Out:
#                                                URL Clean Destination  \
# 3417   https://www.viator.com/Paris-attractions/Eiffe...        d479
# 6279   https://www.viator.com/Paris-attractions/Eiffe...        d479
# 11102  https://www.viator.com/Paris-attractions/Mouli...        d479
# 4285   https://www.viator.com/Paris-attractions/Louvr...        d479
# 491    https://www.viator.com/Paris-attractions/Mouli...        d479
# 5200   https://www.viator.com/Rome-attractions/Vatica...        d511
# 10479  https://www.viator.com/Paris-attractions/Mouli...        d479
# 4082   https://www.viator.com/Barcelona-attractions/L...        d562
# 1717   https://www.viator.com/Rome-attractions/Coloss...        d511
# 2033   https://www.viator.com/Rome-attractions/Vatica...        d511
# 8242   https://www.viator.com/London-attractions/Lond...        d737
# 11374  https://www.viator.com/San-Francisco-attractio...        d651
# 1961   https://www.viator.com/London-attractions/Buck...        d737
# 5229   https://www.viator.com/San-Francisco-attractio...        d651
# 2342   https://www.viator.com/Tokyo-attractions/Mt-Fu...        d334
# 11602  https://www.viator.com/Krakow-attractions/Ausc...        d529
# 89     https://www.viator.com/London-attractions/Ston...        d737
# 10804  https://www.viator.com/Tokyo-attractions/Robot...        d334
# 1252   https://www.viator.com/Milan-attractions/Da-Vi...        d512
# 8200   https://www.viator.com/Krakow-attractions/Ausc...        d529
# 10565  https://www.viator.com/Tokyo-attractions/Robot...        d334
# 9921   https://www.viator.com/San-Francisco-attractio...        d651
# 2168   https://www.viator.com/Dubai-attractions/Burj-...        d828
# 1941   https://www.viator.com/London-attractions/Towe...        d737
# 1371   https://www.viator.com/Dublin-attractions/Clif...        d503
# 63     https://www.viator.com/Sydney-attractions/Sydn...        d357
# 3229   https://www.viator.com/Rome-attractions/Sistin...        d511
# 684    https://www.viator.com/Las-Vegas-attractions/H...        d684
# 5896   https://www.viator.com/Cancun-attractions/Chic...        d631
# 4509   https://www.viator.com/Paris-attractions/Eiffe...        d479
# ...                                                  ...         ...
# 4791   https://www.viator.com/Cusco-attractions/Machu...        d937
# 4798   https://www.viator.com/Beijing-attractions/Gre...        d321
# 4953   https://www.viator.com/New-Delhi-attractions/T...        d804
# 4800   https://www.viator.com/Paris-attractions/Giver...        d479
# 4951   https://www.viator.com/Rome-attractions/Vatica...        d511
# 4949   https://www.viator.com/Santorini-attractions/S...        d959
# 4947   https://www.viator.com/Cairns-and-the-Tropical...        d754
# 4944   https://www.viator.com/Riviera-Maya-and-the-Yu...        d770
# 4937   https://www.viator.com/Las-Vegas-attractions/H...        d684
# 4908   https://www.viator.com/Paris-attractions/Giver...        d479
# 4907   https://www.viator.com/Beijing-attractions/Gre...        d321
# 4906   https://www.viator.com/Bordeaux-attractions/Sa...        d468
# 4899   https://www.viator.com/Seville-attractions/Alc...        d556
# 4898   https://www.viator.com/Brisbane-attractions/Lo...        d363
# 4887   https://www.viator.com/Auckland-attractions/Wa...        d391
# 4886   https://www.viator.com/Lapland-attractions/Arc...       d5581
# 4882   https://www.viator.com/Big-Island-of-Hawaii-at...        d669
# 4875   https://www.viator.com/Las-Vegas-attractions/B...        d684
# 4871   https://www.viator.com/Singapore-attractions/S...         d18
# 4870   https://www.viator.com/Krakow-attractions/Ausc...        d529
# 4868   https://www.viator.com/San-Francisco-attractio...        d651
# 4867   https://www.viator.com/London-attractions/Ston...        d737
# 4855   https://www.viator.com/Cusco-attractions/Machu...        d937
# 4850   https://www.viator.com/Tahiti-attractions/Pape...         d25
# 4848   https://www.viator.com/Lisbon-attractions/Sint...        d538
# 4844   https://www.viator.com/Japan-attractions/Hiros...         d16
# 4817   https://www.viator.com/Chicago-attractions/Wil...        d673
# 4815   https://www.viator.com/Milan-attractions/Da-Vi...        d512
# 4803   https://www.viator.com/El-Calafate-attractions...        d935
# 11737  https://www.viator.com/Paris-attractions/Eiffe...        d479
#
#       Attraction  Conversions
# 3417         a89          138
# 6279         a89          135
# 11102       a576           76
# 4285         a73           58
# 491         a576           52
# 5200        a710           47
# 10479       a576           34
# 4082        a845           31
# 1717        a701           30
# 2033        a710           29
# 8242       a1400           29
# 11374        a88           27
# 1961         a84           27
# 5229        a112           26
# 2342         a86           25
# 11602       a783           23
# 89          a113           22
# 10804     a22115           22
# 1252        a727           21
# 8200        a783           21
# 10565     a22115           20
# 9921        a112           20
# 2168       a1622           20
# 1941         a93           19
# 1371        a668           19
# 63          a106           19
# 3229        a706           17
# 684          a11           17
# 5896         a78           17
# 4509         a89           16
# ...          ...          ...
# 4791       a3358            1
# 4798        a170            1
# 4953       a3010            1
# 4800        a571            1
# 4951        a710            1
# 4949       a5075            1
# 4947       a1443            1
# 4944      a14485            1
# 4937         a11            1
# 4908        a571            1
# 4907      a10136            1
# 4906       a4659            1
# 4899       a3139            1
# 4898        a331            1
# 4887        a432            1
# 4886      a15610            1
# 4882       a1155            1
# 4875       a2955            1
# 4871         a36            1
# 4870        a783            1
# 4868        a112            1
# 4867        a113            1
# 4855       a3358            1
# 4850       a2676            1
# 4848       a3542            1
# 4844        a203            1
# 4817       a1215            1
# 4815        a727            1
# 4803       a2764            1
# 11737        a89            1
#
# [2436 rows x 4 columns]

# %%
df_attractions.loc[3417]['URL Clean']
# Out:
# 'https://www.viator.com/Paris-attractions/Eiffel-Tower-tours-tickets/d479-a89'
