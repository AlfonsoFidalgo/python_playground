# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('ES_price_exten_clean.xlsx')

# %%
df.head(50)
# Out:
#                      Campaign                     Header  \
# 0            Spanish - Alaska  Puerto Cruceros Anchorage
# 1            Spanish - Alaska            Glaciar Portage
# 2            Spanish - Alaska     Parque Estatal Chugach
# 3            Spanish - Alaska     Parque Nacional Denali
# 4            Spanish - Alaska      Centro del Patrimonio
# 5            Spanish - Alaska          Glaciar Matanuska
# 6            Spanish - Alaska            Earthquake Park
# 7            Spanish - Alaska      Excursiones de un Día
# 8            Spanish - Alaska            Cosas que Hacer
# 9   Spanish - All Pages (DSA)        Tours en Nueva York
# 10  Spanish - All Pages (DSA)             Tours en Paris
# 11  Spanish - All Pages (DSA)         Tours en Las Vegas
# 12  Spanish - All Pages (DSA)              Tours en Roma
# 13        Spanish - Amsterdam    Crucero por los Canales
# 14        Spanish - Amsterdam   Molinos de Zaanse Schans
# ...

# %%
df['URL Category'].unique()
# Out:
# array(['Attraction', 'Group/Category', 'TTD', 'Recommendation'], dtype=object)

# %%
sns.boxplot(x='URL Category', y='Price from USD', data=df).set_ylim(0, 120)
# Out:
# (0, 120)

# %%
df[['URL Category', 'Price from USD']].groupby(by='URL Category').count()
# Out:
#                 Price from USD
# URL Category
# Attraction                1251
# Group/Category             469
# Recommendation              21
# TTD                        187

# %%
sns.distplot(df[df['URL Category'] == 'TTD']['Price from USD']).set_xlim(0, 200)
sns.distplot(df[df['URL Category'] == 'Attraction']['Price from USD']).set_xlim(0, 200)
# Out:
# C:\Users\afidalgo\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
# (0, 200)

# %%
sns.distplot(df[df['URL Category'] == 'Attraction']['price int']).set_xlim(0, 200)
# Out:
# C:\Users\afidalgo\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
# (0, 200)

# %%
df['price int'] = df['Price from USD'].apply(lambda x: int(x))

# %%
df.tail()
# Out:
#                   Campaign                   Header               Description  \
# 1923  Spanish - Washington            Museo Chihuly  Miles de Tours en Viator
# 1924  Spanish - Washington       Mercado Pike Place  Miles de Tours en Viator
# 1925  Spanish - Washington  Parque Nacional Olympic  Miles de Tours en Viator
# 1926  Spanish - Washington      Boeing Space Center  Miles de Tours en Viator
# 1927  Spanish - Washington             Space Needle  Miles de Tours en Viator
#
#                                               Final URL  Price from USD  \
# 1923  https://es.viator.com/es/7380/Seattle-attracti...           23.10
# 1924  https://es.viator.com/es/7380/Seattle-attracti...           48.21
# 1925  https://es.viator.com/es/7380/Seattle-attracti...           70.00
# 1926  https://es.viator.com/es/7380/Seattle-attracti...           75.00
# 1927  https://es.viator.com/es/7380/Seattle-attracti...           23.10
#
#          URL type URL Category  price int
# ...
